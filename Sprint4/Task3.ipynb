// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидуальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// Базовый класс Student
//
// ### Вариант задания 2

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Student в C#, который будет представлять информацию о студентах. На основе этого класса разработать 2-3 производных класса, демонстрирующих принципы наследования и полиморфизма. В каждом из классов должны быть реализованы новые атрибуты и методы, а также переопределены некоторые методы базового класса для демонстрации полиморфизма.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) создайте явную реализации интерфейса и управление зависимостями

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public interface IStudent
{
    void Study();
    void TakeExam();
    string GetInfo();
    double CalculateGPA(double[] grades);
}

public interface IResearch
{
    void ConductResearch();
    void PublishArticle();
}

public class Student : IStudent
{
    private string _name;
    private int _age;
    private int _course;
    
    public string Name
    {
        get { return _name; }
        set { _name = value; }
    }
    
    public int Age
    {
        get { return _age; }
        set 
        { 
            if (value >= 16 && value <= 70)
                _age = value;
        }
    }
    
    public int Course
    {
        get { return _course; }
        set 
        { 
            if (value >= 1 && value <= 6)
                _course = value;
        }
    }
    
    public string Email { get; set; }
    public double GPA { get; set; }
    public string StudentId { get; set; }
    public bool IsActive { get; set; }
    
    public static int TotalStudents { get; private set; } = 0;
    
    public Student(string name, int age, int course)
    {
        Name = name;
        Age = age;
        Course = course;
        IsActive = true;
        TotalStudents++;
    }
    
    public virtual string GetInfo()
    {
        return $"Студент: {Name}, Возраст: {Age}, Курс: {Course}";
    }
    
    void IStudent.Study()
    {
        Console.WriteLine($"{Name} изучает обязательные дисциплины");
    }
    
    void IStudent.TakeExam()
    {
        Console.WriteLine($"{Name} проходит итоговую аттестацию");
    }
    
    double IStudent.CalculateGPA(double[] grades)
    {
        double sum = 0;
        foreach (double grade in grades)
            sum += grade;
        GPA = sum / grades.Length;
        return GPA;
    }
    
    public virtual void Study()
    {
        Console.WriteLine($"{Name} посещает учебные занятия");
    }
    
    public virtual void TakeExam()
    {
        Console.WriteLine($"{Name} сдаёт экзамен по учебному плану");
    }
    
    public virtual void CalculateGPA(double[] grades)
    {
        double sum = 0;
        foreach (double grade in grades)
            sum += grade;
        GPA = sum / grades.Length;
        Console.WriteLine($"{Name} имеет средний балл: {GPA:F2}");
    }
    
    public void UpdateEmail(string email)
    {
        Email = email;
        Console.WriteLine($"{Name} зарегистрирован с email: {email}");
    }
    
    public void GenerateStudentId()
    {
        StudentId = $"ST{DateTime.Now:yyyyMMddHHmmss}";
        Console.WriteLine($"{Name} идентификатор: {StudentId}");
    }
    
    public void ChangeStatus(bool isActive)
    {
        IsActive = isActive;
        Console.WriteLine($"{Name} статус изменен на: {(isActive ? "активен" : "неактивен")}");
    }
    
    public static void DisplayTotalStudents()
    {
        Console.WriteLine($"Всего студентов в системе: {TotalStudents}");
    }
}

public class BachelorStudent : Student
{
    private string _specialty;
    
    public string Specialty
    {
        get { return _specialty; }
        set { _specialty = value; }
    }
    
    public string Faculty { get; set; }
    public int Scholarship { get; set; }
    public bool HasDormitory { get; set; }
    public string ClubMembership { get; set; }
    public int PracticeHours { get; set; }
    
    public BachelorStudent(string name, int age, int course, string specialty) 
        : base(name, age, course)
    {
        Specialty = specialty;
    }
    
    public override string GetInfo()
    {
        return base.GetInfo() + $", Специальность: {Specialty}, Факультет: {Faculty}";
    }
    
    public override void Study()
    {
        Console.WriteLine($"{Name} изучает базовые дисциплины по специальности '{Specialty}'");
    }
    
    public void JoinClub(string clubName)
    {
        ClubMembership = clubName;
        Console.WriteLine($"{Name} участвует в деятельности клуба: {clubName}");
    }
    
    public void CompletePractice(int hours)
    {
        PracticeHours += hours;
        Console.WriteLine($"{Name} завершил практику, общее количество часов: {PracticeHours}");
    }
    
    public void ApplyForScholarship()
    {
        Console.WriteLine($"{Name} подает документы на академическую стипендию");
    }
}

public class MasterStudent : Student, IResearch
{
    private string _scientificAdvisor;
    
    public string ScientificAdvisor
    {
        get { return _scientificAdvisor; }
        set { _scientificAdvisor = value; }
    }
    
    public string ResearchTopic { get; set; }
    public string ThesisTitle { get; set; }
    public bool HasPublication { get; set; }
    public string ResearchGroup { get; set; }
    public int ConferenceCount { get; set; }
    
    public MasterStudent(string name, int age, int course, string scientificAdvisor) 
        : base(name, age, course)
    {
        ScientificAdvisor = scientificAdvisor;
    }
    
    public override string GetInfo()
    {
        return base.GetInfo() + $", Руководитель: {ScientificAdvisor}, Тема: {ResearchTopic}";
    }
    
    public void ConductResearch()
    {
        Console.WriteLine($"{Name} проводит научное исследование: '{ResearchTopic}'");
    }
    
    public void PublishArticle()
    {
        HasPublication = true;
        Console.WriteLine($"{Name} опубликовал статью в научном журнале");
    }
    
    public void SubmitThesis()
    {
        Console.WriteLine($"{Name} представляет магистерскую диссертацию: '{ThesisTitle}'");
    }
    
    public void AttendConference(string conferenceName)
    {
        ConferenceCount++;
        Console.WriteLine($"{Name} выступает на конференции: {conferenceName}");
    }
}

public class PhDStudent : Student, IResearch
{
    private string _dissertationTopic;
    
    public string DissertationTopic
    {
        get { return _dissertationTopic; }
        set { _dissertationTopic = value; }
    }
    
    public string ResearchGroup { get; set; }
    public int PublicationsCount { get; set; }
    public string DefenseDate { get; set; }
    public string ResearchFunding { get; set; }
    public bool IsDissertationCompleted { get; set; }
    
    public PhDStudent(string name, int age, int course, string dissertationTopic) 
        : base(name, age, course)
    {
        DissertationTopic = dissertationTopic;
    }
    
    public override string GetInfo()
    {
        return base.GetInfo() + $", Диссертация: '{DissertationTopic}', Группа: {ResearchGroup}";
    }
    
    public void ConductResearch()
    {
        Console.WriteLine($"{Name} проводит фундаментальное исследование: '{DissertationTopic}'");
    }
    
    public void PublishArticle()
    {
        PublicationsCount++;
        Console.WriteLine($"{Name} опубликовал научную статью. Всего публикаций: {PublicationsCount}");
    }
    
    public void DefendDissertation()
    {
        IsDissertationCompleted = true;
        Console.WriteLine($"{Name} успешно защитил диссертацию '{DissertationTopic}'");
    }
    
    public void ReceiveGrant(string grantName)
    {
        ResearchFunding = grantName;
        Console.WriteLine($"{Name} получил исследовательский грант: {grantName}");
    }
}

public class StudentService
{
    private readonly IStudent _student;
    
    public StudentService(IStudent student)
    {
        _student = student;
    }
    
    public void ProcessAcademicWork()
    {
        _student.Study();
        _student.TakeExam();
        double[] grades = { 4.5, 4.0, 4.2, 4.7, 4.8 };
        double gpa = _student.CalculateGPA(grades);
        Console.WriteLine($"{_student.GetInfo()} - GPA: {gpa:F2}");
    }
}

public class ResearchService
{
    private readonly IResearch _researcher;
    
    public ResearchService(IResearch researcher)
    {
        _researcher = researcher;
    }
    
    public void ConductResearchActivities()
    {
        _researcher.ConductResearch();
        _researcher.PublishArticle();
    }
}

BachelorStudent bachelor = new BachelorStudent("Вероника Никольская", 19, 2, "Информатика");
MasterStudent master = new MasterStudent("Елена Ковальчук", 21, 3, "д.т.н. Волков");
PhDStudent phd = new PhDStudent("Геннадий Тяжелов", 23, 4, "Нейросети в медицине");

bachelor.Faculty = "Факультет информационных технологий";
bachelor.Scholarship = 1500;
bachelor.HasDormitory = true;

master.ResearchTopic = "Машинное обучение";
master.ThesisTitle = "Алгоритмы глубокого обучения";
master.ResearchGroup = "AI Research";

phd.ResearchGroup = "Neural Networks Lab";
phd.DefenseDate = "15.12.2024";
phd.PublicationsCount = 3;

bachelor.UpdateEmail("veronika.nikolskaya@edu.ru");
master.UpdateEmail("elena.kovalchuk@edu.ru");
phd.UpdateEmail("genady.tyachlov@edu.ru");

Console.WriteLine("Информация о студентах:");
Console.WriteLine(bachelor.GetInfo());
Console.WriteLine(master.GetInfo());
Console.WriteLine(phd.GetInfo());

Console.WriteLine("Учебная деятельность:");
bachelor.Study();
master.Study();
phd.Study();

Console.WriteLine("Экзаменационная сессия:");
bachelor.TakeExam();
master.TakeExam();
phd.TakeExam();

Console.WriteLine("Научная работа:");
master.ConductResearch();
master.PublishArticle();
phd.ConductResearch();
phd.PublishArticle();

Console.WriteLine("Сервисы с dependency injection:");
StudentService bachelorService = new StudentService(bachelor);
StudentService masterService = new StudentService(master);
bachelorService.ProcessAcademicWork();
masterService.ProcessAcademicWork();

ResearchService researchService = new ResearchService(phd);
researchService.ConductResearchActivities();

Console.WriteLine("Дополнительная активность:");
bachelor.JoinClub("Программирование");
bachelor.CompletePractice(120);
master.AttendConference("International AI Conference");
master.SubmitThesis();
phd.ReceiveGrant("РНФ №24-456");
phd.DefendDissertation();

Student.DisplayTotalStudents();
// Out:
// Вероника Никольская зарегистрирован с email: veronika.nikolskaya@edu.ru
// Елена Ковальчук зарегистрирован с email: elena.kovalchuk@edu.ru
// Геннадий Тяжелов зарегистрирован с email: genady.tyachlov@edu.ru
// Информация о студентах:
// Студент: Вероника Никольская, Возраст: 19, Курс: 2, Специальность: Информатика, Факультет: Факультет информационных технологий
// Студент: Елена Ковальчук, Возраст: 21, Курс: 3, Руководитель: д.т.н. Волков, Тема: Машинное обучение
// Студент: Геннадий Тяжелов, Возраст: 23, Курс: 4, Диссертация: 'Нейросети в медицине', Группа: Neural Networks Lab
// Учебная деятельность:
// Вероника Никольская изучает базовые дисциплины по специальности 'Информатика'
// Елена Ковальчук посещает учебные занятия
// Геннадий Тяжелов посещает учебные занятия
// Экзаменационная сессия:
// Вероника Никольская сдаёт экзамен по учебному плану
// Елена Ковальчук сдаёт экзамен по учебному плану
// Геннадий Тяжелов сдаёт экзамен по учебному плану
// Научная работа:
// ...
